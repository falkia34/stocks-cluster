# %% [markdown]
# # Import dependencies

# %%
import pandas as pd
import os
import glob
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# # Load stock data

# %%
stock_list = pd.read_csv('../data/stock-list.csv', delimiter=';')

# %%
stock_list.sample(5)
# Out:
#       No  Kode                Nama Perusahaan Tanggal Pencatatan       Saham  \
# 926  927  BRRC       Raja Roti Cemerlang Tbk.         09/01/2025   971500000
# 714  715  HOPE      Harapan Duta Pertiwi Tbk.         24/05/2021  2130360203
# 811  812  LAJU  Jasa Berdikari Logistics Tbk.         27/01/2023  2149942974
# 789  790  CBUT        Citra Borneo Utama Tbk.         08/11/2022  3125000000
# 612  613  SFAN       Surya Fajar Capital Tbk.         19/06/2019  1359934021
#
#       Papan Pencatatan
# 926       Pengembangan
# 714  Pemantauan Khusus
# 811       Pengembangan
# 789       Pengembangan
# 612       Pengembangan

# %%
stock_codes = stock_list['Kode'].tolist()

# %% [markdown]
# # Summarize stock columns

# %%
def suffix_duplicate(input_list):
    counts = {}
    result = []
    for item in input_list:
        if item in counts:
            counts[item] += 1
            result.append(f"{item}_{counts[item]}")
        else:
            counts[item] = 0
            result.append(item)
    return result

# %%
stock_columns = pd.DataFrame()

for stock_code in stock_codes:
    print(f'Processing stock code: {stock_code}')

    financials_path = os.path.join(
        '..', 'data', 'financials', stock_code, 'annual', '*.csv')

    financials = glob.glob(financials_path)

    stock_column = pd.DataFrame(columns=['Kode'])
    # Fill first row with stock code
    stock_column.loc[0, 'Kode'] = stock_code

    for financial in financials:
        # Read the stock financials from CSV file
        df = pd.read_csv(financial, index_col=None, header=0)
        # Get the column names
        column = df.columns.tolist()
        # Make a DataFrame with column names above and add single row and fill each column with true
        df_column = pd.DataFrame(columns=column)
        df_column.loc[0] = [True] * len(column)

        stock_column = pd.concat([stock_column, df_column], axis=1)

    stock_column.columns = suffix_duplicate(stock_column.columns.tolist())

    stock_columns = pd.concat([stock_columns, stock_column], ignore_index=True)

stock_columns = stock_columns.fillna(False)

stock_columns.head()
# Out:
# Processing stock code: AALI
# Processing stock code: ABBA
# Processing stock code: ABDA
# Processing stock code: ABMM
# Processing stock code: ACES
# Processing stock code: ACST
# Processing stock code: ADES
# Processing stock code: ADHI
# Processing stock code: ADMF
# Processing stock code: ADMG
# Processing stock code: ADRO
# Processing stock code: AGII
# Processing stock code: AGRO
# Processing stock code: AGRS
# Processing stock code: AHAP
# Processing stock code: AIMS
# Processing stock code: AISA
# Processing stock code: AKKU
# Processing stock code: AKPI
# Processing stock code: AKRA
# Processing stock code: AKSI
# Processing stock code: ALDO
# Processing stock code: ALKA
# Processing stock code: ALMI
# Processing stock code: ALTO
# Processing stock code: AMAG
# Processing stock code: AMFG
# Processing stock code: AMIN
# Processing stock code: AMRT
# Processing stock code: ANJT
# Processing stock code: ANTM
# Processing stock code: APEX
# Processing stock code: APIC
# Processing stock code: APII
# Processing stock code: APLI
# Processing stock code: APLN
# Processing stock code: ARGO
# Processing stock code: ARII
# Processing stock code: ARNA
# Processing stock code: ARTA
# Processing stock code: ARTI
# Processing stock code: ARTO
# Processing stock code: ASBI
# Processing stock code: ASDM
# Processing stock code: ASGR
# Processing stock code: ASII
# Processing stock code: ASJT
# Processing stock code: ASMI
# Processing stock code: ASRI
# Processing stock code: ASRM
# Processing stock code: ASSA
# Processing stock code: ATIC
# Processing stock code: AUTO
# Processing stock code: BABP
# Processing stock code: BACA
# Processing stock code: BAJA
# Processing stock code: BALI
# Processing stock code: BAPA
# Processing stock code: BATA
# Processing stock code: BAYU
# Processing stock code: BBCA
# Processing stock code: BBHI
# Processing stock code: BBKP
# Processing stock code: BBLD
# Processing stock code: BBMD
# Processing stock code: BBNI
# Processing stock code: BBRI
# Processing stock code: BBRM
# Processing stock code: BBTN
# Processing stock code: BBYB
# Processing stock code: BCAP
# Processing stock code: BCIC
# Processing stock code: BCIP
# Processing stock code: BDMN
# Processing stock code: BEKS
# Processing stock code: BEST
# Processing stock code: BFIN
# Processing stock code: BGTG
# Processing stock code: BHIT
# Processing stock code: BIKA
# Processing stock code: BIMA
# Processing stock code: BINA
# Processing stock code: BIPI
# Processing stock code: BIPP
# Processing stock code: BIRD
# Processing stock code: BISI
# Processing stock code: BJBR
# Processing stock code: BJTM
# Processing stock code: BKDP
# Processing stock code: BKSL
# Processing stock code: BKSW
# Processing stock code: BLTA
# Processing stock code: BLTZ
# Processing stock code: BMAS
# Processing stock code: BMRI
# Processing stock code: BMSR
# Processing stock code: BMTR
# Processing stock code: BNBA
# Processing stock code: BNBR
# Processing stock code: BNGA
# Processing stock code: BNII
# Processing stock code: BNLI
# Processing stock code: BOLT
# Processing stock code: BPFI
# Processing stock code: BPII
# Processing stock code: BRAM
# Processing stock code: BRMS
# Processing stock code: BRNA
# Processing stock code: BRPT
# Processing stock code: BSDE
# Processing stock code: BSIM
# Processing stock code: BSSR
# Processing stock code: BSWD
# Processing stock code: BTEK
# Processing stock code: BTEL
# Processing stock code: BTON
# Processing stock code: BTPN
# Processing stock code: BUDI
# Processing stock code: BUKK
# Processing stock code: BULL
# Processing stock code: BUMI
# Processing stock code: BUVA
# Processing stock code: BVIC
# Processing stock code: BWPT
# Processing stock code: BYAN
# Processing stock code: CANI
# Processing stock code: CASS
# Processing stock code: CEKA
# Processing stock code: CENT
# Processing stock code: CFIN
# Processing stock code: CINT
# Processing stock code: CITA
# Processing stock code: CLPI
# Processing stock code: CMNP
# Processing stock code: CMPP
# Processing stock code: CNKO
# Processing stock code: CNTX
# Processing stock code: COWL
# Processing stock code: CPIN
# Processing stock code: CPRO
# Processing stock code: CSAP
# Processing stock code: CTBN
# Processing stock code: CTRA
# Processing stock code: CTTH
# Processing stock code: DART
# Processing stock code: DEFI
# Processing stock code: DEWA
# Processing stock code: DGIK
# Processing stock code: DILD
# Processing stock code: DKFT
# Processing stock code: DLTA
# Processing stock code: DMAS
# Processing stock code: DNAR
# Processing stock code: DNET
# Processing stock code: DOID
# Processing stock code: DPNS
# Processing stock code: DSFI
# Processing stock code: DSNG
# Processing stock code: DSSA
# Processing stock code: DUTI
# Processing stock code: DVLA
# Processing stock code: DYAN
# Processing stock code: ECII
# Processing stock code: EKAD
# Processing stock code: ELSA
# Processing stock code: ELTY
# Processing stock code: EMDE
# Processing stock code: EMTK
# Processing stock code: ENRG
# Processing stock code: EPMT
# Processing stock code: ERAA
# Processing stock code: ERTX
# Processing stock code: ESSA
# Processing stock code: ESTI
# Processing stock code: ETWA
# Processing stock code: EXCL
# Processing stock code: FAST
# Processing stock code: FASW
# Processing stock code: FISH
# Processing stock code: FMII
# Processing stock code: FORU
# Processing stock code: FPNI
# Processing stock code: GAMA
# Processing stock code: GDST
# Processing stock code: GDYR
# Processing stock code: GEMA
# Processing stock code: GEMS
# Processing stock code: GGRM
# Processing stock code: GIAA
# Processing stock code: GJTL
# Processing stock code: GLOB
# Processing stock code: GMTD
# Processing stock code: GOLD
# Processing stock code: GOLL
# Processing stock code: GPRA
# Processing stock code: GSMF
# Processing stock code: GTBO
# Processing stock code: GWSA
# Processing stock code: GZCO
# Processing stock code: HADE
# Processing stock code: HDFA
# Processing stock code: HDTX
# Processing stock code: HERO
# Processing stock code: HEXA
# Processing stock code: HITS
# Processing stock code: HMSP
# Processing stock code: HOME
# Processing stock code: HOTL
# Processing stock code: HRUM
# Processing stock code: IATA
# Processing stock code: IBFN
# Processing stock code: IBST
# Processing stock code: ICBP
# Processing stock code: ICON
# Processing stock code: IGAR
# Processing stock code: IIKP
# Processing stock code: IKAI
# Processing stock code: IKBI
# Processing stock code: IMAS
# Processing stock code: IMJS
# Processing stock code: IMPC
# Processing stock code: INAF
# Processing stock code: INAI
# Processing stock code: INCI
# Processing stock code: INCO
# Processing stock code: INDF
# Processing stock code: INDR
# Processing stock code: INDS
# Processing stock code: INDX
# Processing stock code: INDY
# Processing stock code: INKP
# Processing stock code: INPC
# Processing stock code: INPP
# Processing stock code: INRU
# Processing stock code: INTA
# Processing stock code: INTD
# Processing stock code: INTP
# Processing stock code: IPOL
# Processing stock code: ISAT
# Processing stock code: ISSP
# Processing stock code: ITMA
# Processing stock code: ITMG
# Processing stock code: JAWA
# Processing stock code: JECC
# Processing stock code: JIHD
# Processing stock code: JKON
# Processing stock code: JKSW
# Processing stock code: JPFA
# Processing stock code: JRPT
# Processing stock code: JSMR
# Processing stock code: JSPT
# Processing stock code: JTPE
# Processing stock code: KAEF
# Processing stock code: KARW
# Processing stock code: KBLI
# Processing stock code: KBLM
# Processing stock code: KBLV
# Processing stock code: KBRI
# Processing stock code: KDSI
# Processing stock code: KIAS
# Processing stock code: KICI
# Processing stock code: KIJA
# Processing stock code: KKGI
# Processing stock code: KLBF
# Processing stock code: KOBX
# Processing stock code: KOIN
# Processing stock code: KONI
# Processing stock code: KOPI
# Processing stock code: KPIG
# Processing stock code: KRAH
# Processing stock code: KRAS
# Processing stock code: KREN
# Processing stock code: LAPD
# Processing stock code: LCGP
# Processing stock code: LEAD
# Processing stock code: LINK
# Processing stock code: LION
# Processing stock code: LMAS
# Processing stock code: LMPI
# Processing stock code: LMSH
# Processing stock code: LPCK
# Processing stock code: LPGI
# Processing stock code: LPIN
# Processing stock code: LPKR
# Processing stock code: LPLI
# Processing stock code: LPPF
# Processing stock code: LPPS
# Processing stock code: LRNA
# Processing stock code: LSIP
# Processing stock code: LTLS
# Processing stock code: MAGP
# Processing stock code: MAIN
# Processing stock code: MAMI
# Processing stock code: MAPI
# Processing stock code: MASA
# Processing stock code: MAYA
# Processing stock code: MBAP
# Processing stock code: MBSS
# Processing stock code: MBTO
# Processing stock code: MCOR
# Processing stock code: MDIA
# Processing stock code: MDKA
# Processing stock code: MDLN
# Processing stock code: MDRN
# Processing stock code: MEDC
# Processing stock code: MEGA
# Processing stock code: MERK
# Processing stock code: META
# Processing stock code: MFIN
# Processing stock code: MFMI
# Processing stock code: MGNA
# Processing stock code: MICE
# Processing stock code: MIDI
# Processing stock code: MIKA
# Processing stock code: MIRA
# Processing stock code: MITI
# Processing stock code: MKPI
# Processing stock code: MLBI
# Processing stock code: MLIA
# Processing stock code: MLPL
# Processing stock code: MLPT
# Processing stock code: MMLP
# Processing stock code: MNCN
# Processing stock code: MPMX
# Processing stock code: MPPA
# Processing stock code: MRAT
# Processing stock code: MREI
# Processing stock code: MSKY
# Processing stock code: MTDL
# Processing stock code: MTFN
# Processing stock code: MTLA
# Processing stock code: MTSM
# Processing stock code: MYOH
# Processing stock code: MYOR
# Processing stock code: MYRX
# Processing stock code: MYTX
# Processing stock code: NELY
# Processing stock code: NIKL
# Processing stock code: NIPS
# Processing stock code: NIRO
# Processing stock code: NISP
# Processing stock code: NOBU
# Processing stock code: NRCA
# Processing stock code: OCAP
# Processing stock code: OKAS
# Processing stock code: OMRE
# Processing stock code: PADI
# Processing stock code: PALM
# Processing stock code: PANR
# Processing stock code: PANS
# Processing stock code: PBRX
# Processing stock code: PDES
# Processing stock code: PEGE
# Processing stock code: PGAS
# Processing stock code: PGLI
# Processing stock code: PICO
# Processing stock code: PJAA
# Processing stock code: PKPK
# Processing stock code: PLAS
# Processing stock code: PLIN
# Processing stock code: PNBN
# Processing stock code: PNBS
# Processing stock code: PNIN
# Processing stock code: PNLF
# Processing stock code: PNSE
# Processing stock code: POLY
# Processing stock code: POOL
# Processing stock code: PPRO
# Processing stock code: PRAS
# Processing stock code: PSAB
# Processing stock code: PSDN
# Processing stock code: PSKT
# Processing stock code: PTBA
# Processing stock code: PTIS
# Processing stock code: PTPP
# Processing stock code: PTRO
# Processing stock code: PTSN
# Processing stock code: PTSP
# Processing stock code: PUDP
# Processing stock code: PWON
# Processing stock code: PYFA
# Processing stock code: RAJA
# Processing stock code: RALS
# Processing stock code: RANC
# Processing stock code: RBMS
# Processing stock code: RDTX
# Processing stock code: RELI
# Processing stock code: RICY
# Processing stock code: RIGS
# Processing stock code: RIMO
# Processing stock code: RODA
# Processing stock code: ROTI
# Processing stock code: RUIS
# Processing stock code: SAFE
# Processing stock code: SAME
# Processing stock code: SCCO
# Processing stock code: SCMA
# Processing stock code: SCPI
# Processing stock code: SDMU
# Processing stock code: SDPC
# Processing stock code: SDRA
# Processing stock code: SGRO
# Processing stock code: SHID
# Processing stock code: SIDO
# Processing stock code: SILO
# Processing stock code: SIMA
# Processing stock code: SIMP
# Processing stock code: SIPD
# Processing stock code: SKBM
# Processing stock code: SKLT
# Processing stock code: SKYB
# Processing stock code: SMAR
# Processing stock code: SMBR
# Processing stock code: SMCB
# Processing stock code: SMDM
# Processing stock code: SMDR
# Processing stock code: SMGR
# Processing stock code: SMMA
# Processing stock code: SMMT
# Processing stock code: SMRA
# Processing stock code: SMRU
# Processing stock code: SMSM
# Processing stock code: SOCI
# Processing stock code: SONA
# Processing stock code: SPMA
# Processing stock code: SQMI
# Processing stock code: SRAJ
# Processing stock code: SRIL
# Processing stock code: SRSN
# Processing stock code: SRTG
# Processing stock code: SSIA
# Processing stock code: SSMS
# Processing stock code: SSTM
# Processing stock code: STAR
# Processing stock code: STTP
# Processing stock code: SUGI
# Processing stock code: SULI
# Processing stock code: SUPR
# Processing stock code: TALF
# Processing stock code: TARA
# Processing stock code: TAXI
# Processing stock code: TBIG
# Processing stock code: TBLA
# Processing stock code: TBMS
# Processing stock code: TCID
# Processing stock code: TELE
# Processing stock code: TFCO
# Processing stock code: TGKA
# Processing stock code: TIFA
# Processing stock code: TINS
# Processing stock code: TIRA
# Processing stock code: TIRT
# Processing stock code: TKIM
# Processing stock code: TLKM
# Processing stock code: TMAS
# Processing stock code: TMPO
# Processing stock code: TOBA
# Processing stock code: TOTL
# Processing stock code: TOTO
# Processing stock code: TOWR
# Processing stock code: TPIA
# Processing stock code: TPMA
# Processing stock code: TRAM
# Processing stock code: TRIL
# Processing stock code: TRIM
# Processing stock code: TRIO
# Processing stock code: TRIS
# Processing stock code: TRST
# Processing stock code: TRUS
# Processing stock code: TSPC
# Processing stock code: ULTJ
# Processing stock code: UNIC
# Processing stock code: UNIT
# Processing stock code: UNSP
# Processing stock code: UNTR
# Processing stock code: UNVR
# Processing stock code: VICO
# Processing stock code: VINS
# Processing stock code: VIVA
# Processing stock code: VOKS
# Processing stock code: VRNA
# Processing stock code: WAPO
# Processing stock code: WEHA
# Processing stock code: WICO
# Processing stock code: WIIM
# Processing stock code: WIKA
# Processing stock code: WINS
# Processing stock code: WOMF
# Processing stock code: WSKT
# Processing stock code: WTON
# Processing stock code: YPAS
# Processing stock code: YULE
# Processing stock code: ZBRA
# Processing stock code: SHIP
# Processing stock code: CASA
# Processing stock code: DAYA
# Processing stock code: DPUM
# Processing stock code: IDPR
# Processing stock code: JGLE
# Processing stock code: KINO
# Processing stock code: MARI
# Processing stock code: MKNT
# Processing stock code: MTRA
# Processing stock code: OASA
# Processing stock code: POWR
# Processing stock code: INCF
# Processing stock code: WSBP
# Processing stock code: PBSA
# Processing stock code: PRDA
# Processing stock code: BOGA
# Processing stock code: BRIS
# Processing stock code: PORT
# Processing stock code: CARS
# Processing stock code: MINA
# Processing stock code: FORZ
# Processing stock code: CLEO
# Processing stock code: TAMU
# Processing stock code: CSIS
# Processing stock code: TGRA
# Processing stock code: FIRE
# Processing stock code: TOPS
# Processing stock code: KMTR
# Processing stock code: ARMY
# Processing stock code: MAPB
# Processing stock code: WOOD
# Processing stock code: HRTA
# Processing stock code: MABA
# Processing stock code: HOKI
# Processing stock code: MPOW
# Processing stock code: MARK
# Processing stock code: NASA
# Processing stock code: MDKI
# Processing stock code: BELL
# Processing stock code: KIOS
# Processing stock code: GMFI
# Processing stock code: MTWI
# Processing stock code: ZINC
# Processing stock code: MCAS
# Processing stock code: PPRE
# Processing stock code: WEGE
# Processing stock code: PSSI
# Processing stock code: MORA
# Processing stock code: DWGL
# Processing stock code: PBID
# Processing stock code: JMAS
# Processing stock code: CAMP
# Processing stock code: IPCM
# Processing stock code: PCAR
# Processing stock code: LCKM
# Processing stock code: BOSS
# Processing stock code: HELI
# Processing stock code: JSKY
# Processing stock code: INPS
# Processing stock code: GHON
# Processing stock code: TDPM
# Processing stock code: DFAM
# Processing stock code: NICK
# Processing stock code: BTPS
# Processing stock code: SPTO
# Processing stock code: PRIM
# Processing stock code: HEAL
# Processing stock code: TRUK
# Processing stock code: PZZA
# Processing stock code: TUGU
# Processing stock code: MSIN
# Processing stock code: SWAT
# Processing stock code: KPAL
# Processing stock code: TNCA
# Processing stock code: MAPA
# Processing stock code: TCPI
# Processing stock code: IPCC
# Processing stock code: RISE
# Processing stock code: BPTR
# Processing stock code: POLL
# Processing stock code: NFCX
# Processing stock code: MGRO
# Processing stock code: NUSA
# Processing stock code: FILM
# Processing stock code: ANDI
# Processing stock code: LAND
# Processing stock code: MOLI
# Processing stock code: PANI
# Processing stock code: DIGI
# Processing stock code: CITY
# Processing stock code: SAPX
# Processing stock code: KPAS
# Processing stock code: SURE
# Processing stock code: HKMU
# Processing stock code: MPRO
# Processing stock code: DUCK
# Processing stock code: GOOD
# Processing stock code: SKRN
# Processing stock code: YELO
# Processing stock code: CAKK
# Processing stock code: SATU
# Processing stock code: ZONE
# Processing stock code: PEHA
# Processing stock code: FOOD
# Processing stock code: BEEF
# Processing stock code: POLI
# Processing stock code: CLAY
# Processing stock code: NATO
# Processing stock code: JAYA
# Processing stock code: COCO
# Processing stock code: MTPS
# Processing stock code: CPRI
# Processing stock code: HRME
# Processing stock code: POSA
# Processing stock code: JAST
# Processing stock code: FITT
# Processing stock code: BOLA
# Processing stock code: CCSI
# Processing stock code: SFAN
# Processing stock code: POLU
# Processing stock code: KJEN
# Processing stock code: KAYU
# Processing stock code: ITIC
# Processing stock code: PAMG
# Processing stock code: IPTV
# Processing stock code: BLUE
# Processing stock code: ENVY
# Processing stock code: EAST
# Processing stock code: LIFE
# Processing stock code: FUJI
# Processing stock code: KOTA
# Processing stock code: INOV
# Processing stock code: ARKA
# Processing stock code: SMKL
# Processing stock code: HDIT
# Processing stock code: KEEN
# Processing stock code: BAPI
# Processing stock code: TFAS
# Processing stock code: GGRP
# Processing stock code: OPMS
# Processing stock code: NZIA
# Processing stock code: SLIS
# Processing stock code: PURE
# Processing stock code: IRRA
# Processing stock code: DMMX
# Processing stock code: SINI
# Processing stock code: WOWS
# Processing stock code: ESIP
# Processing stock code: TEBE
# Processing stock code: KEJU
# Processing stock code: PSGO
# Processing stock code: AGAR
# Processing stock code: IFSH
# Processing stock code: REAL
# Processing stock code: IFII
# Processing stock code: PMJS
# Processing stock code: UCID
# Processing stock code: GLVA
# Processing stock code: PGJO
# Processing stock code: AMAR
# Processing stock code: CSRA
# Processing stock code: INDO
# Processing stock code: AMOR
# Processing stock code: TRIN
# Processing stock code: DMND
# Processing stock code: PURA
# Processing stock code: PTPW
# Processing stock code: TAMA
# Processing stock code: IKAN
# Processing stock code: AYLS
# Processing stock code: DADA
# Processing stock code: ASPI
# Processing stock code: ESTA
# Processing stock code: BESS
# Processing stock code: CSMI
# Processing stock code: BBSS
# Processing stock code: BHAT
# Processing stock code: CASH
# Processing stock code: TECH
# Processing stock code: EPAC
# Processing stock code: UANG
# Processing stock code: PGUN
# Processing stock code: SOFA
# Processing stock code: PPGL
# Processing stock code: TOYS
# Processing stock code: SGER
# Processing stock code: TRJA
# Processing stock code: PNGO
# Processing stock code: SCNP
# Processing stock code: BBSI
# Processing stock code: KMDS
# Processing stock code: PURI
# Processing stock code: SOHO
# Processing stock code: HOMI
# Processing stock code: ROCK
# Processing stock code: ENZO
# Processing stock code: PLAN
# Processing stock code: PTDU
# Processing stock code: ATAP
# Processing stock code: VICI
# Processing stock code: PMMP
# Processing stock code: WIFI
# Processing stock code: FAPA
# Processing stock code: DCII
# Processing stock code: KETR
# Processing stock code: DGNS
# Processing stock code: UFOE
# Processing stock code: BANK
# Processing stock code: WMUU
# Processing stock code: EDGE
# Processing stock code: UNIQ
# Processing stock code: BEBS
# Processing stock code: SNLK
# Processing stock code: ZYRX
# Processing stock code: LFLO
# Processing stock code: FIMP
# Processing stock code: TAPG
# Processing stock code: NPGF
# Processing stock code: LUCY
# Processing stock code: ADCP
# Processing stock code: HOPE
# Processing stock code: MGLV
# Processing stock code: TRUE
# Processing stock code: LABA
# Processing stock code: ARCI
# Processing stock code: IPAC
# Processing stock code: MASB
# Processing stock code: BMHS
# Processing stock code: FLMC
# Processing stock code: NICL
# Processing stock code: UVCR
# Processing stock code: BUKA
# Processing stock code: HAIS
# Processing stock code: OILS
# Processing stock code: GPSO
# Processing stock code: MCOL
# Processing stock code: RSGK
# Processing stock code: RUNS
# Processing stock code: SBMA
# Processing stock code: CMNT
# Processing stock code: GTSI
# Processing stock code: IDEA
# Processing stock code: KUAS
# Processing stock code: BOBA
# Processing stock code: MTEL
# Processing stock code: DEPO
# Processing stock code: BINO
# Processing stock code: CMRY
# Processing stock code: WGSH
# Processing stock code: TAYS
# Processing stock code: WMPP
# Processing stock code: RMKE
# Processing stock code: OBMD
# Processing stock code: AVIA
# Processing stock code: IPPE
# Processing stock code: NASI
# Processing stock code: BSML
# Processing stock code: DRMA
# Processing stock code: ADMR
# Processing stock code: SEMA
# Processing stock code: ASLC
# Processing stock code: NETV
# Processing stock code: BAUT
# Processing stock code: ENAK
# Processing stock code: NTBK
# Processing stock code: SMKM
# Processing stock code: STAA
# Processing stock code: NANO
# Processing stock code: BIKE
# Processing stock code: WIRG
# Processing stock code: SICO
# Processing stock code: GOTO
# Processing stock code: TLDN
# Processing stock code: MTMH
# Processing stock code: WINR
# Processing stock code: IBOS
# Processing stock code: OLIV
# Processing stock code: ASHA
# Processing stock code: SWID
# Processing stock code: TRGU
# Processing stock code: ARKO
# Processing stock code: CHEM
# Processing stock code: DEWI
# Processing stock code: AXIO
# Processing stock code: KRYA
# Processing stock code: HATM
# Processing stock code: RCCC
# Processing stock code: GULA
# Processing stock code: JARR
# Processing stock code: AMMS
# Processing stock code: BUAH
# Processing stock code: CRAB
# Processing stock code: MEDS
# Processing stock code: COAL
# Processing stock code: PRAY
# Processing stock code: CBUT
# Processing stock code: BELI
# Processing stock code: MKTR
# Processing stock code: OMED
# Processing stock code: BSBK
# Processing stock code: PDPP
# Processing stock code: KDTN
# Processing stock code: ZATA
# Processing stock code: NINE
# Processing stock code: MMIX
# Processing stock code: PADA
# Processing stock code: ISAP
# Processing stock code: VTNY
# Processing stock code: SOUL
# Processing stock code: ELIT
# Processing stock code: BEER
# Processing stock code: CBPE
# Processing stock code: SUNI
# Processing stock code: CBRE
# Processing stock code: WINE
# Processing stock code: BMBL
# Processing stock code: PEVE
# Processing stock code: LAJU
# Processing stock code: FWCT
# Processing stock code: NAYZ
# Processing stock code: IRSX
# Processing stock code: PACK
# Processing stock code: VAST
# Processing stock code: CHIP
# Processing stock code: HALO
# Processing stock code: KING
# Processing stock code: PGEO
# Processing stock code: FUTR
# Processing stock code: HILL
# Processing stock code: BDKR
# Processing stock code: PTMP
# Processing stock code: SAGE
# Processing stock code: TRON
# Processing stock code: CUAN
# Processing stock code: NSSS
# Processing stock code: GTRA
# Processing stock code: HAJJ
# Processing stock code: PIPA
# Processing stock code: NCKL
# Processing stock code: MENN
# Processing stock code: AWAN
# Processing stock code: MBMA
# Processing stock code: RAAM
# Processing stock code: DOOH
# Processing stock code: JATI
# Processing stock code: TYRE
# Processing stock code: MPXL
# Processing stock code: SMIL
# Processing stock code: KLAS
# Processing stock code: MAXI
# Processing stock code: VKTR
# Processing stock code: RELF
# Processing stock code: AMMN
# Processing stock code: CRSN
# Processing stock code: GRPM
# Processing stock code: WIDI
# Processing stock code: TGUK
# Processing stock code: INET
# Processing stock code: MAHA
# Processing stock code: RMKO
# Processing stock code: CNMA
# Processing stock code: FOLK
# Processing stock code: HBAT
# Processing stock code: GRIA
# Processing stock code: PPRI
# Processing stock code: ERAL
# Processing stock code: CYBR
# Processing stock code: MUTU
# Processing stock code: LMAX
# Processing stock code: HUMI
# Processing stock code: MSIE
# Processing stock code: RSCH
# Processing stock code: BABY
# Processing stock code: AEGS
# Processing stock code: IOTF
# Processing stock code: KOCI
# Processing stock code: PTPS
# Processing stock code: BREN
# Processing stock code: STRK
# Processing stock code: KOKA
# Processing stock code: LOPI
# Processing stock code: UDNG
# Processing stock code: RGAS
# Processing stock code: MSTI
# Processing stock code: IKPM
# Processing stock code: AYAM
# Processing stock code: SURI
# Processing stock code: ASLI
# Processing stock code: CGAS
# Processing stock code: NICE
# Processing stock code: MSJA
# Processing stock code: SMLE
# Processing stock code: ACRO
# Processing stock code: MANG
# Processing stock code: GRPH
# Processing stock code: SMGA
# Processing stock code: UNTD
# Processing stock code: TOSK
# Processing stock code: MPIX
# Processing stock code: ALII
# Processing stock code: MKAP
# Processing stock code: MEJA
# Processing stock code: LIVE
# Processing stock code: HYGN
# Processing stock code: BAIK
# Processing stock code: VISI
# Processing stock code: AREA
# Processing stock code: MHKI
# Processing stock code: ATLA
# Processing stock code: DATA
# Processing stock code: SOLA
# Processing stock code: BATR
# Processing stock code: SPRE
# Processing stock code: PART
# Processing stock code: GOLF
# Processing stock code: ISEA
# Processing stock code: BLES
# Processing stock code: GUNA
# Processing stock code: LABS
# Processing stock code: DOSS
# Processing stock code: NEST
# Processing stock code: PTMR
# Processing stock code: VERN
# Processing stock code: DAAZ
# Processing stock code: BOAT
# Processing stock code: NAIK
# Processing stock code: AADI
# Processing stock code: MDIY
# Processing stock code: KSIX
# Processing stock code: RATU
# Processing stock code: YOII
# Processing stock code: HGII
# Processing stock code: BRRC
# Processing stock code: DGWG
# Processing stock code: CBDK
# Processing stock code: OBAT
# Processing stock code: MINE
# Processing stock code: KAQI
# Processing stock code: YUPI
# Processing stock code: FORE
# Processing stock code: MDLA
# Processing stock code: DKHH
# Processing stock code: SOSS
# Processing stock code: DEAL
# Processing stock code: POLA
# Processing stock code: DIVA
# Processing stock code: LUCK
# Processing stock code: URBN
# Processing stock code: SOTS
# Processing stock code: AMAN
# Processing stock code: CARE
# Processing stock code: SAMF
# Processing stock code: SBAT
# Processing stock code: KBAG
# Processing stock code: CBMF
# Processing stock code: RONY
# Processing stock code: RAFI
# Processing stock code: KKES
# Processing stock code: ELPI
# Processing stock code: EURO
# Processing stock code: KLIN
# Processing stock code: TOOL
# C:\Users\Rulim\AppData\Local\Temp\ipykernel_13752\1593773940.py:35: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stock_columns = stock_columns.fillna(False)
#    Kode  Period  Aset  Aset Lancar  Kas Dan Setara Kas  Piutang Usaha  \
# 0  AALI    True  True         True                True           True
# 1  ABBA    True  True         True                True           True
# 2  ABDA    True  True        False                True          False
# 3  ABMM    True  True         True                True           True
# 4  ACES    True  True         True                True           True
#
#    Pihak Ketiga  Pihak Berelasi  Total Piutang Usaha  Piutang Lain-Lain  ...  \
# 0          True            True                 True               True  ...
# 1          True            True                 True               True  ...
# 2          True            True                False               True  ...
# 3          True            True                 True               True  ...
# 4          True            True                 True               True  ...
#
#    Pembayaran Jaminan Yang Dapat Dikembalikan  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
#
#    Penambahan Modal Saham Dan Tambahan Modal Disetor Melalui Penawaran Umum Perdana  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Penerimaan Dari Penjualan Aset Tetap Melalui Jual Dan Sewa Balik  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Pembayaran Dari Utang Lembaga Keuangan Lainnya  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    Penerimaan Dari Utang Lembaga Keuangan Lainnya  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    Penambahan Utang Pemegang Saham  \
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False
#
#    Penerimaan Modal Kepentingan Non-Pengendali  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
#
#    Pembayaran Kepada Pinjaman Bank  Pembayaran Kepada Pinjaman Pemegang Saham  \
# 0                            False                                      False
# 1                            False                                      False
# 2                            False                                      False
# 3                            False                                      False
# 4                            False                                      False
#
#    Pembayaran Kepada Piutang Lain-Lain Pihak Berelasi
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
# [5 rows x 14419 columns]

# %%
 # Save the stock columns DataFrame to CSV file
stock_columns.to_csv('../data/stock-columns.csv', index=False)

# %%
# Sort the columns by the most True values, excluding the 'Kode' column
by=stock_columns.drop(columns=['Kode']).sum().sort_values(ascending=False).index
stock_columns = stock_columns[['Kode'] + list(by)]

# %%
stock_columns.head()
# Out:
#    Kode  Period  Liabilitas Dan Ekuitas  Liabilitas  \
# 0  AALI    True                    True        True
# 1  ABBA    True                    True        True
# 2  ABDA    True                    True        True
# 3  ABMM    True                    True        True
# 4  ACES    True                    True        True
#
#    Tang. Book Value Per Share (Annual)  Short-term Debt (Annual)  \
# 0                                 True                      True
# 1                                 True                      True
# 2                                 True                      True
# 3                                 True                      True
# 4                                 True                      True
#
#    Book Value Per Share (Annual)  Price to Tang. Book Value (Annual)  \
# 0                           True                                True
# 1                           True                                True
# 2                           True                                True
# 3                           True                                True
# 4                           True                                True
#
#    Saham Beredar  Total Liabilitas  ...  \
# 0           True              True  ...
# 1           True              True  ...
# 2           True              True  ...
# 3           True              True  ...
# 4           True              True  ...
#
#    Pembayaran Dari Utang Lembaga Keuangan Lainnya  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    Penerimaan Dari Penjualan Aset Tetap Melalui Jual Dan Sewa Balik  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Penambahan Modal Saham Dan Tambahan Modal Disetor Melalui Penawaran Umum Perdana  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Pembayaran Jaminan Yang Dapat Dikembalikan  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
#
#    Penempatan Uang Muka Pendaftaran Merk  Penempatan Uang Muka Aset Tetap  \
# 0                                  False                            False
# 1                                  False                            False
# 2                                  False                            False
# 3                                  False                            False
# 4                                  False                            False
#
#    Pengembalian Uang Muka Pembelian Mesin  Penempatan Uang Muka Mesin  \
# 0                                   False                       False
# 1                                   False                       False
# 2                                   False                       False
# 3                                   False                       False
# 4                                   False                       False
#
#    Penempatan Uang Muka Konstruksi  \
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False
#
#    Pengurangan Deposito Berjangka Dan Giro Yang Dijaminkan
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
# [5 rows x 14419 columns]

# %%
# Get the list of columns and the count of True values for each column
column_true_counts = stock_columns.drop(columns=['Kode']).sum().reset_index()
column_true_counts.columns = ['Column', 'True Count']

# %%
column_true_counts.head()
# Out:
#                                 Column  True Count
# 0                               Period         956
# 1               Liabilitas Dan Ekuitas         956
# 2                           Liabilitas         956
# 3  Tang. Book Value Per Share (Annual)         956
# 4             Short-term Debt (Annual)         956

# %%
# Get the list of columns that are available in all stock codes
available_in_all = column_true_counts[column_true_counts['True Count'] == len(stock_codes)]
available_in_all = available_in_all['Column'].tolist()

# %%
# Print the columns that are available in all stock codes
print("Columns available in all stock codes:")
for column in available_in_all:
    print(column)
# Out:
# Columns available in all stock codes:
# Period
# Liabilitas Dan Ekuitas
# Liabilitas
# Tang. Book Value Per Share (Annual)
# Short-term Debt (Annual)
# Book Value Per Share (Annual)
# Price to Tang. Book Value (Annual)
# Saham Beredar
# Total Liabilitas
# Ekuitas
# Receivables Turnover (Annual)
# Receivables Turnover (TTM)
# Inventory Turnover (Annual)
# Aset
# Total Aset
# Fixed Assets Turnover (Annual)
# Laba Usaha
# Total Arus Kas Dari Aktivitas Investasi
# Working Capital Turnover (TTM)
# Working Capital Turnover (Annual)
# Asset Turnover (TTM)
# Asset Turnover (Annual)
# Fixed Assets Turnover (TTM)
# Long-term Debt (Annual)
# Working Capital Ratio (Annual)
# Period_4
# Financial Leverage (Annual)
# Total Debt (Annual)
# Net Debt (Annual)
# Arus Kas Dari Aktivitas Investasi
# Quick Ratio (Annual)
# Total Ekuitas
# Total Liabilitas Dan Ekuitas
# Price to Book Value (Annual)
# Period_1
# Inventory Turnover (TTM)
# LT Debt/Equity (Annual)
# LT Debt/Total Assets (Annual)
# Debt to Equity Ratio (Annual)
# Net Debt/Total Equity (Annual)
# Total Debt/Total Assets (Annual)
# Period_3
# Total Liabilities/Equity (Annual)
# Days Sales Outstanding (Annual)
# Payables Period (Annual)
# Cash Conversion Cycle (Annual)
# Arus Kas Dari Aktivitas Pendanaan
# Arus Kas Dari Aktivitas Operasi
# Period_2
# Current Ratio (Annual)
# Others.1
# Others
# Laba Komprehensif Yang Dapat Diatribusikan Kepada
# Pemilik Entitas Induk.1
# Period_6
# Price to Sales (Annual)
# Share Outstanding
# EPS (Annual)
# PE Ratio (Annual)
# Beban Pajak Penghasilan
# Laba Sebelum Pajak
# Laba Bersih Tahun Berjalan
# Pendapatan Komprehensif Lain
# Return on Assets (Annual)
# EBITDA (Annual)
# Total Pendapatan
# Total Beban Usaha
# Total Laba Bersih Yang Dapat Diatribusikan Kepada
# Interest Coverage (Annual)
# Return on Equity (Annual)
# Return on Capital Employed (Annual)
# Period_5
# Free cash flow (Annual)
# Free cash flow per share (Annual)
# Operating Cash Flow (Annual)
# Laba Bersih Yang Dapat Diatribusikan Kepada
# Pemilik Entitas Induk
# Capital expenditure (Annual)
# Days Inventory (Annual)
# Kas Dan Setara Kas
# Working capital (Annual)
# Period_7
